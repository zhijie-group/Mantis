# %% [markdown]
# ### 图像识别实验

# %% [markdown]
# #### pi05，language instruction1

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Put the cup on the female singer" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/54b3a3c1-7e36-4456-9e86-9d05f97ddfe4/02917b2f-fd83-47af-9067-0fd4c4291f68/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Put the cup on the basketball player" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/54b3a3c1-7e36-4456-9e86-9d05f97ddfe4/02917b2f-fd83-47af-9067-0fd4c4291f68/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Put the cup on the Marvel superhero" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/54b3a3c1-7e36-4456-9e86-9d05f97ddfe4/02917b2f-fd83-47af-9067-0fd4c4291f68/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Put the cup on the English playwright" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/54b3a3c1-7e36-4456-9e86-9d05f97ddfe4/02917b2f-fd83-47af-9067-0fd4c4291f68/proxy/8000/"

# %% [markdown]
# #### pi05，language instruction2

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Put the cup on Taylor Swift, a famous American singer-songwriter" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/a2143a00-5201-4404-a106-0ffc32475c72/2d33a4d9-8df8-4ef9-a2ba-918b3b9859fe/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Put the cup on Michael Jordan, a legendary NBA basketball player" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/a2143a00-5201-4404-a106-0ffc32475c72/2d33a4d9-8df8-4ef9-a2ba-918b3b9859fe/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Put the cup on Iron Man, Marvel's armored superhero" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/a2143a00-5201-4404-a106-0ffc32475c72/2d33a4d9-8df8-4ef9-a2ba-918b3b9859fe/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Put the cup on Shakespeare, an influential English playwright and poet" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/a2143a00-5201-4404-a106-0ffc32475c72/2d33a4d9-8df8-4ef9-a2ba-918b3b9859fe/proxy/8000/"

# %% [markdown]
# #### pi05，language instruction3

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "1" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/292652f4-24d7-4a87-8211-72f81260ce6b/90f99e28-0ddb-416f-a86f-348be5ccc30c/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "2" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/292652f4-24d7-4a87-8211-72f81260ce6b/90f99e28-0ddb-416f-a86f-348be5ccc30c/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "3" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/292652f4-24d7-4a87-8211-72f81260ce6b/90f99e28-0ddb-416f-a86f-348be5ccc30c/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "4" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/292652f4-24d7-4a87-8211-72f81260ce6b/90f99e28-0ddb-416f-a86f-348be5ccc30c/proxy/8000/"

# %% [markdown]
# ### 物品识别实验

# %% [markdown]
# #### pi05，language instruction1

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Pick up the bottle and place it in the basket" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/e68e45d0-2887-45ca-88e5-7e216527600f/7a77339e-6061-45fd-8483-0195f177cef3/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Pick up the Rubik's Cube and place it in the basket" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/e68e45d0-2887-45ca-88e5-7e216527600f/7a77339e-6061-45fd-8483-0195f177cef3/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Pick up the bread and place it in the basket" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/e68e45d0-2887-45ca-88e5-7e216527600f/7a77339e-6061-45fd-8483-0195f177cef3/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Pick up the watch and place it in the basket" --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/e68e45d0-2887-45ca-88e5-7e216527600f/7a77339e-6061-45fd-8483-0195f177cef3/proxy/8000/"

# %% [markdown]
# #### pi05，language instruction2

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "I'm thirsty. Please put the drink bottle in the basket" --openpi_host "https://ai-notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/54936b8a-bd04-4dec-b280-a5b321782211/66e5b008-20df-499c-bf38-f22802ec5cce/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "I want to play with toys. Please put the Rubik's Cube in the basket" --openpi_host "https://ai-notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/54936b8a-bd04-4dec-b280-a5b321782211/66e5b008-20df-499c-bf38-f22802ec5cce/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "It's breakfast time. Pick up the bread and place it in the basket" --openpi_host "https://ai-notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/54936b8a-bd04-4dec-b280-a5b321782211/66e5b008-20df-499c-bf38-f22802ec5cce/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "I want to know the time. Please put the watch in the basket" --openpi_host "https://ai-notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/54936b8a-bd04-4dec-b280-a5b321782211/66e5b008-20df-499c-bf38-f22802ec5cce/proxy/8000/"

# %% [markdown]
# #### pi05，language instruction3

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "1" --openpi_host "https://ai-notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/ba6f3783-1f7f-4398-9244-923d921237d6/e2eb864a-4df9-4ef4-863b-f1debcff9cec/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "2" --openpi_host "https://ai-notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/ba6f3783-1f7f-4398-9244-923d921237d6/e2eb864a-4df9-4ef4-863b-f1debcff9cec/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "3" --openpi_host "https://ai-notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/ba6f3783-1f7f-4398-9244-923d921237d6/e2eb864a-4df9-4ef4-863b-f1debcff9cec/proxy/8000/"

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "4" --openpi_host "https://ai-notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/ba6f3783-1f7f-4398-9244-923d921237d6/e2eb864a-4df9-4ef4-863b-f1debcff9cec/proxy/8000/"

# %%
pi05_aloha_iclr_bear_and_cabinet_success_1

# %%
/inspire/hdd/project/robot-action/lixueqi-240108540151/openpi05/openpi/checkpoints/pi05_aloha_iclr_bear_and_cabinet_success_1/full_data_train/29999

# %%
uv run scripts/compute_norm_stats.py --config-name pi05_aloha_iclr_bear_and_cabinet_success_1

# %%
XLA_PYTHON_CLIENT_MEM_FRACTION=0.9 uv run scripts/train.py pi05_aloha_iclr_bear_and_cabinet_success_1 --exp-name=full_data_train --overwrite

# %%
uv run scripts/serve_policy_fastapi_msgpack.py --port 8000 policy:checkpoint --policy.config=pi05_aloha_iclr_bear_and_cabinet_success_1 --policy.dir=/inspire/hdd/project/robot-action/lixueqi-240108540151/openpi05/openpi/checkpoints/pi05_aloha_iclr_bear_and_cabinet_success_1/full_data_train/29999

# %%
python ./act/inference_openpi_fastapi_msgpack.py --task_instruction "Take the teddy bear out of the cabinet and put it in the basket." --openpi_host "https://notebook-inspire.sii.edu.cn/ws-9dcc0e1f-80a4-4af2-bc2f-0e352e7b17e6/project-3365c7ce-af12-4ea8-b5c3-5826e504190c/user-fdda2138-977e-4a4d-b96a-99a7568d6867/vscode/36dcbd0c-9591-44ce-868b-ca00a98ab13d/41b9b6e5-8b7f-4e3a-b13f-138cfb8f478a/proxy/8000/"

# %%
好
