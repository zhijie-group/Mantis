# %%
python ./act/inference_cvpr.py --task_instruction "Put the teddy bear on the number 8" --openpi_host "https://nat-notebook-inspire.sii.edu.cn/ws-6040202d-b785-4b37-98b0-c68d65dd52ce/project-6ee538a7-4c8b-410c-9653-77111474b204/user-a6086624-79f5-4839-af3d-ad958cf9a91f/vscode/c4d0764e-277f-43a0-944b-393c5ca3e564/d51945dc-0fe4-4ff3-8203-de7a50634323/proxy/8000/"

# %%
./act/inference_cvpr.py:250: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
  if "error" in server_result:
model cost time:  1.0185933113098145
Exception in thread Thread-15:
Traceback (most recent call last):
  File "/home/agilex/miniconda3/envs/aloha/lib/python3.8/threading.py", line 932, in _bootstrap_inner
    self.run()
  File "/home/agilex/miniconda3/envs/aloha/lib/python3.8/threading.py", line 870, in run
    self._target(*self._args, **self._kwargs)
  File "./act/inference_cvpr.py", line 255, in inference_process
    inference_actions = server_result["actions"]
IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
roslaunch piper start_ms_piper.launch mode:=1 auto_enable:=true

# %% [markdown]
# Put the cup on the female singer
# Put the cup on the basketball player
# Put the cup on the Marvel superhero
# Put the cup on the English playwright

# %% [markdown]
# I'm thirsty. Could you give me a hand?
# I'm bored and need something to kill time. Could you give me a hand?
# I feel hungry. Could you give me a hand?
# I want to wear something on my wrist. Could you give me a hand?
